# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
plt
# Out:
# <module 'matplotlib.pyplot' from 'c:\\users\\inki\\appdata\\local\\programs\\python\\python36-32\\lib\\site-packages\\matplotlib\\pyplot.py'>

# %%
plt.plot([1, 2, 3, 4], [2, 3, 5, 7])

# %%
plt.plot(np.arange(1, 10), np.arange(100, 1000, 100))

# %%
x = np.linspace(0, 1, 10)

plt.plot(x, x, label='linear')

# %%
x = np.linspace(0, 2, 100)

plt.plot(x, x, label='linear')
plt.plot(x, x**2, label='quadratic')
plt.plot(x, x**3, label='cubic')

plt.xlabel('x label')
plt.ylabel('y label')
plt.legend()

# %%
plt.show()

# %%
plt.scatter([1, 2, 3, 4], [2, 3, 5, 7])

# %%
plt.scatter(np.arange(50), np.arange(50) ** 2)

# %%
x = np.arange(50)
y = x + np.random.randint(0, 50, 50)

color = np.random.randint(0, 50, 50)
size = np.random.randint(0, 50, 50)

plt.scatter(x, y, c=color, s=size)

# %%
np.random.randint(0, 10)
# Out:
# 5

# %%
np.random.randint(0, 10, (4, 5))
# Out:
# array([[5, 7, 9, 3, 1],
#        [6, 9, 0, 0, 0],
#        [1, 2, 5, 6, 2],
#        [6, 8, 4, 2, 7]])

# %%
import pandas as pd

# %%
pd.Series([2, 3, 5, 7, 11])
# Out:
# 0     2
# 1     3
# 2     5
# 3     7
# 4    11
# dtype: int64

# %%
pd.Series(np.random.randint(0, 10, 10))
# Out:
# 0    0
# 1    4
# 2    0
# 3    9
# 4    7
# 5    4
# 6    8
# 7    7
# 8    5
# 9    0
# dtype: int32

# %%
s = pd.Series(np.random.randint(0, 10, 4), index=['apple', 'orange', 'banana', 'kiwi'])
s
# Out:
# apple     8
# orange    1
# banana    6
# kiwi      6
# dtype: int32

# %%
s[0]
# Out:
# 8

# %%
s['apple']
# Out:
# 8

# %%
pd.Series(np.random.randn(5), index=['a', 'b', 'c', 'd', 'e'])
# Out:
# a   -1.476477
# b    1.905952
# c   -0.509460
# d    0.369980
# e   -0.597303
# dtype: float64

# %%
pd.DataFrame([[1, 2, 3, 4], [5, 6, 7, 8]])  # list of lists
# Out:
#    0  1  2  3
# 0  1  2  3  4
# 1  5  6  7  8

# %%
pd.DataFrame({'x': [1, 2, 3, 4], 'y': [5, 6, 7, 8]})  # dict of lists
# Out:
#    x  y
# 0  1  5
# 1  2  6
# 2  3  7
# 3  4  8

# %%
pd.DataFrame({'x': [1, 2, 3, 4], 'y': [5, 6, 7, 8]}, index=['a', 'b', 'c', 'd'])
# Out:
#    x  y
# a  1  5
# b  2  6
# c  3  7
# d  4  8
